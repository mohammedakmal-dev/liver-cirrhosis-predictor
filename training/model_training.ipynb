# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("liver_data.csv")
df.head()
# Out:
#    Age  Gender    TB   DB  Alkphos  Sgpt  Sgot   TP  ALB  A/G Ratio  Selector
# 0   65  Female   0.7  0.1      187    16    18  6.8  3.3       0.90         1
# 1   62    Male  10.9  5.5      699    64   100  7.5  3.2       0.74         1
# 2   62    Male   7.3  4.1      490    60    68  7.0  3.3       0.89         1
# 3   58    Male   1.0  0.4      182    14    20  6.8  3.4       1.00         1
# 4   72    Male   3.9  2.0      195    27    59  7.3  2.4       0.40         1

# %%
df.info()
df.describe()
df.isnull().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 583 entries, 0 to 582
# Data columns (total 11 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Age        583 non-null    int64
#  1   Gender     583 non-null    object
#  2   TB         583 non-null    float64
#  3   DB         583 non-null    float64
#  4   Alkphos    583 non-null    int64
#  5   Sgpt       583 non-null    int64
#  6   Sgot       583 non-null    int64
#  7   TP         583 non-null    float64
#  8   ALB        583 non-null    float64
#  9   A/G Ratio  579 non-null    float64
#  10  Selector   583 non-null    int64
# dtypes: float64(5), int64(5), object(1)
# memory usage: 50.2+ KB
# Age          0
# Gender       0
# TB           0
# DB           0
# Alkphos      0
# Sgpt         0
# Sgot         0
# TP           0
# ALB          0
# A/G Ratio    4
# Selector     0
# dtype: int64

# %%
df = df.dropna()

# %%
print(df.columns)
# Out:
# Index(['Age', 'Gender', 'TB', 'DB', 'Alkphos', 'Sgpt', 'Sgot', 'TP', 'ALB',
#        'A/G Ratio', 'Selector'],
#       dtype='object')

# %%
sns.countplot(x="Selector", data=df)
plt.title("Cirrhosis (1) vs Non-Cirrhosis (2)")
plt.show()

# %%
sns.heatmap(df.corr(), annot=True, cmap="coolwarm")
plt.title("Feature Correlation Matrix")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 sns.heatmap(df.corr(), annot=True, cmap="coolwarm")
#       2 plt.title("Feature Correlation Matrix")
#       3 plt.show()
#
# File ~\liver-cirrhosis-predictor\liver-env\Lib\site-packages\pandas\core\frame.py:11056, in DataFrame.corr(self, method, min_periods, numeric_only)
#   11054 cols = data.columns
#   11055 idx = cols.copy()
# > 11056 mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   11058 if method == "pearson":
#   11059     correl = libalgos.nancorr(mat, minp=min_periods)
#
# File ~\liver-cirrhosis-predictor\liver-env\Lib\site-packages\pandas\core\frame.py:1998, in DataFrame.to_numpy(self, dtype, copy, na_value)
#    1996 if dtype is not None:
#    1997     dtype = np.dtype(dtype)
# -> 1998 result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
#    1999 if result.dtype is not dtype:
#    2000     result = np.asarray(result, dtype=dtype)
#
# File ~\liver-cirrhosis-predictor\liver-env\Lib\site-packages\pandas\core\internals\managers.py:1694, in BlockManager.as_array(self, dtype, copy, na_value)
#    1692         arr.flags.writeable = False
#    1693 else:
# -> 1694     arr = self._interleave(dtype=dtype, na_value=na_value)
#    1695     # The underlying data was copied within _interleave, so no need
#    1696     # to further copy if copy=True or setting na_value
#    1698 if na_value is lib.no_default:
#
# File ~\liver-cirrhosis-predictor\liver-env\Lib\site-packages\pandas\core\internals\managers.py:1753, in BlockManager._interleave(self, dtype, na_value)
#    1751     else:
#    1752         arr = blk.get_values(dtype)
# -> 1753     result[rl.indexer] = arr
#    1754     itemmask[rl.indexer] = 1
#    1756 if not itemmask.all():
#
# ValueError: could not convert string to float: 'Female'

# %%
df["Gender"].unique()
# Out:
# array(['Female', 'Male'], dtype=object)

# %%
df["Gender"] = df["Gender"].map({"Male": 1, "Female": 0})

# %%
sns.heatmap(df.corr(), annot=True, cmap="coolwarm")
plt.title("Feature Correlation Matrix")
plt.show()

# %%
from sklearn.model_selection import train_test_split

X = df.drop("Selector", axis=1)  # Features
y = df["Selector"]               # Target label

X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.3, random_state=42
)

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
from sklearn.ensemble import RandomForestClassifier

model = RandomForestClassifier()
model.fit(X_train_scaled, y_train)
# Out:
# RandomForestClassifier()

# %%
from sklearn.metrics import classification_report, accuracy_score

y_pred = model.predict(X_test_scaled)
print("Accuracy:", accuracy_score(y_test, y_pred))
print(classification_report(y_test, y_pred))
# Out:
# Accuracy: 0.6666666666666666
#               precision    recall  f1-score   support
#
#            1       0.67      0.95      0.79       113
#            2       0.60      0.15      0.24        61
#
#     accuracy                           0.67       174
#    macro avg       0.64      0.55      0.51       174
# weighted avg       0.65      0.67      0.59       174

# %%
import joblib

joblib.dump(model, "../rf_model.pkl")
joblib.dump(scaler, "../normalizer.pkl")
# Out:
# ['../normalizer.pkl']
